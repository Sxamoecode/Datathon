# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.impute as kNNImputer
from sklearn.preprocessing import MinMaxScaler

oilData = pd.read_csv("oil_presence_trainset.csv")

# %%
oilData.head(10)
# Out:
#    Rock_Type   Porosity  Permeability  Trap_Type  Seismic_Score  \
# 0  Limestone  17.667992    834.277472        NaN       0.705933
# 1  Limestone  27.665758    578.158034        NaN       0.545806
# 2  Sandstone  28.855946    404.790685        NaN       0.167530
# 3  Sandstone   0.410957    887.836673       Dome       0.026852
# 4      Shale  16.490538    562.288802        NaN            NaN
# 5      Shale  16.654792    979.154784  Anticline       0.044457
# 6  Limestone   8.342985           NaN      Fault            NaN
# 7      Shale  13.111546    263.806644      Fault       0.375041
# 8      Shale        NaN           NaN      Fault            NaN
# 9  Sandstone  28.419000    728.106328  Anticline       0.194321
#
#    Proximity_to_Oil_Field  Estimated_Reservoir_Depth  Oil_Presence
# 0                2.431355                     2228.0             1
# 1                2.606158                     1610.0             0
# 2                1.143136                     2344.0             0
# 3                2.673532                        NaN             0
# 4                2.064440                        NaN             0
# 5                4.927771                     3556.0             1
# 6                0.439339                        NaN             0
# 7                4.602919                        NaN             0
# 8                0.672804                      867.0             0
# 9                4.097616                        NaN             0

# %%
oilData.describe()
# Out:
#           Porosity  Permeability  Seismic_Score  Proximity_to_Oil_Field  \
# count  2197.000000   1814.000000    1950.000000             2057.000000
# mean     14.762194    505.594049       0.490680                2.545868
# std       8.750759    281.718143       0.286654                1.470783
# min       0.018825      1.185010       0.000333                0.001007
# 25%       7.152815    273.913289       0.245138                1.286000
# 50%      14.602531    504.565289       0.485856                2.550525
# 75%      22.417084    751.803683       0.729728                3.842006
# max      29.992547    997.134762       0.999353                4.998872
#
#        Estimated_Reservoir_Depth  Oil_Presence
# count                1732.000000   3000.000000
# mean                 2764.426674      0.277667
# std                  1288.782908      0.447923
# min                   500.000000      0.000000
# 25%                  1650.500000      0.000000
# 50%                  2772.500000      0.000000
# 75%                  3820.000000      1.000000
# max                  4997.000000      1.000000

# %%
oilData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Rock_Type                  3000 non-null   object
#  1   Porosity                   2197 non-null   float64
#  2   Permeability               1814 non-null   float64
#  3   Trap_Type                  2233 non-null   object
#  4   Seismic_Score              1950 non-null   float64
#  5   Proximity_to_Oil_Field     2057 non-null   float64
#  6   Estimated_Reservoir_Depth  1732 non-null   float64
#  7   Oil_Presence               3000 non-null   int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 187.6+ KB

# %%
cp_row = oilData.dropna() #drop any row with missing data
#cp_row

# %%
x = cp_row.Porosity
y = cp_row.Permeability

plt.scatter(x, y)
plt.show()

# %%
cp_row.describe()
# Out:
#          Porosity  Permeability  Seismic_Score  Proximity_to_Oil_Field  \
# count  242.000000    242.000000     242.000000              242.000000
# mean    15.426316    499.284687       0.485876                2.682992
# std      8.919082    291.527837       0.284503                1.510118
# min      0.048036     18.134529       0.006394                0.003744
# 25%      7.207491    256.740694       0.249579                1.382075
# 50%     16.649783    462.358664       0.446967                2.770711
# 75%     23.301967    751.218879       0.713240                4.021814
# max     29.949563    997.134762       0.997357                4.987292
#
#        Estimated_Reservoir_Depth  Oil_Presence
# count                 242.000000    242.000000
# mean                 2808.475207      0.264463
# std                  1270.591597      0.441961
# min                   517.000000      0.000000
# 25%                  1741.500000      0.000000
# 50%                  2922.000000      0.000000
# 75%                  3885.500000      1.000000
# max                  4945.000000      1.000000

# %%
oilData.isna()
# Out:
#       Rock_Type  Porosity  Permeability  Trap_Type  Seismic_Score  \
# 0         False     False         False       True          False
# 1         False     False         False       True          False
# 2         False     False         False       True          False
# 3         False     False         False      False          False
# 4         False     False         False       True           True
# ...         ...       ...           ...        ...            ...
# 2995      False     False         False      False          False
# 2996      False      True          True      False          False
# 2997      False     False         False      False          False
# 2998      False     False         False      False          False
# 2999      False     False         False      False           True
#
#       Proximity_to_Oil_Field  Estimated_Reservoir_Depth  Oil_Presence
# 0                      False                      False         False
# 1                      False                      False         False
# 2                      False                      False         False
# 3                      False                       True         False
# 4                      False                       True         False
# ...                      ...                        ...           ...
# 2995                    True                      False         False
# 2996                    True                      False         False
# 2997                    True                      False         False
# 2998                   False                       True         False
# 2999                   False                       True         False
#
# [3000 rows x 8 columns]

# %%
from sklearn import impute
df = oilData

#import sklearn.impute as kNNImputer

# %%
# 2. Separate numeric and categorical columns
numeric_cols = [
    "Porosity",
    "Permeability",
    "Seismic_Score",
    "Proximity_to_Oil_Field",
    "Estimated_Reservoir_Depth",
    "Oil_Presence",
]
categorical_cols = ["Rock_Type", "Trap_Type"]

# %%
# Encode categorical text columns
df_encoded = pd.get_dummies(df, columns=categorical_cols, dummy_na=True, dtype=float)

# %%
# Scale the numerical columns to a 0-1 range
scaler = MinMaxScaler()
df_encoded[numeric_cols] = scaler.fit_transform(df_encoded[numeric_cols])

# %%
# Initialize and run the KNN Imputer
imputer = impute.KNNImputer(n_neighbors=5, weights='distance')
imputed_array = imputer.fit_transform(df_encoded)
df_imputed = pd.DataFrame(imputed_array, columns=df_encoded.columns)

# %%
# Inverse-transform to bring numbers back to their original scale
df_imputed[numeric_cols] = scaler.inverse_transform(df_imputed[numeric_cols])

# %%
# Reverse the Encoding back to text categories
for col in categorical_cols:
    dummy_cols = [c for c in df_imputed.columns if c.startswith(f"{col}_")]
    df[col] = df_imputed[dummy_cols].idxmax(axis=1).str.replace(f"{col}_", "")
    df[col] = df[col].replace("nan", np.nan)

# %%
# Assign the final filled Porosity column back to our original dataframe
df["Porosity"] = df_imputed["Porosity"]

# %%
df.head(10)
# Out:
#    Rock_Type   Porosity  Permeability  Trap_Type  Seismic_Score  \
# 0  Limestone  17.667992    834.277472        NaN       0.705933
# 1  Limestone  27.665758    578.158034        NaN       0.545806
# 2  Sandstone  28.855946    404.790685        NaN       0.167530
# 3  Sandstone   0.410957    887.836673       Dome       0.026852
# 4      Shale  16.490538    562.288802        NaN            NaN
# 5      Shale  16.654792    979.154784  Anticline       0.044457
# 6  Limestone   8.342985           NaN      Fault            NaN
# 7      Shale  13.111546    263.806644      Fault       0.375041
# 8      Shale  17.547364           NaN      Fault            NaN
# 9  Sandstone  28.419000    728.106328  Anticline       0.194321
#
#    Proximity_to_Oil_Field  Estimated_Reservoir_Depth  Oil_Presence
# 0                2.431355                     2228.0             1
# 1                2.606158                     1610.0             0
# 2                1.143136                     2344.0             0
# 3                2.673532                        NaN             0
# 4                2.064440                        NaN             0
# 5                4.927771                     3556.0             1
# 6                0.439339                        NaN             0
# 7                4.602919                        NaN             0
# 8                0.672804                      867.0             0
# 9                4.097616                        NaN             0

# %%
print(f"Missing values in Permeability BEFORE: {df['Permeability'].isnull().sum()}")
# Out:
# Missing values in Permeability BEFORE: 1186

# %%
# Separate numeric and categorical columns
numeric_cols = [
    "Porosity",
    "Permeability",
    "Seismic_Score",
    "Proximity_to_Oil_Field",
    "Estimated_Reservoir_Depth",
    "Oil_Presence",
]
categorical_cols = ["Rock_Type", "Trap_Type"]

# %%
# Encode categorical text columns so KNN can calculate distances
df_encoded = pd.get_dummies(df, columns=categorical_cols, dummy_na=True, dtype=float)

# %%
# Scale the numerical columns to a uniform 0-1 range
scaler = MinMaxScaler()
df_encoded[numeric_cols] = scaler.fit_transform(df_encoded[numeric_cols])

# %%
# Initialize and run the KNN Imputer (Looking at 5 nearest neighbors)
imputer = impute.KNNImputer(n_neighbors=5, weights='distance')
imputed_array = imputer.fit_transform(df_encoded)

# %%
# Convert the resulting numpy array back into a structured DataFrame
df_imputed = pd.DataFrame(imputed_array, columns=df_encoded.columns)

# %%
# Inverse-transform to scale the numbers back to their original physical units
df_imputed[numeric_cols] = scaler.inverse_transform(df_imputed[numeric_cols])

# %%
# 7. Assign the perfectly imputed Permeability column back to your original DataFrame
df["Permeability"] = df_imputed["Permeability"]

# %%
print(f"Missing values in Permeability AFTER: {df['Permeability'].isnull().sum()}")
# Out:
# Missing values in Permeability AFTER: 0

# %%
df.head(30)
# Out:
#     Rock_Type   Porosity  Permeability  Trap_Type  Seismic_Score  \
# 0   Limestone  17.667992    834.277472        NaN       0.705933
# 1   Limestone  27.665758    578.158034        NaN       0.545806
# 2   Sandstone  28.855946    404.790685        NaN       0.167530
# 3   Sandstone   0.410957    887.836673       Dome       0.026852
# 4       Shale  16.490538    562.288802        NaN            NaN
# 5       Shale  16.654792    979.154784  Anticline       0.044457
# 6   Limestone   8.342985           NaN      Fault            NaN
# 7       Shale  13.111546    263.806644      Fault       0.375041
# 8       Shale  17.547364           NaN      Fault            NaN
# 9   Sandstone  28.419000    728.106328  Anticline       0.194321
# 10  Limestone   9.656027     33.591597      Fault       0.751546
# 11  Limestone   8.582698    734.733917      Fault            NaN
# 12      Shale  12.221468           NaN  Anticline       0.002469
# 13  Sandstone  14.973260    634.181591      Fault            NaN
# 14  Limestone  21.513617    481.242733      Fault            NaN
# 15  Sandstone  27.100080    415.349595      Fault       0.262536
# 16  Limestone   2.645337    989.530440      Fault       0.151013
# 17  Sandstone  20.538637    286.076025        NaN       0.972294
# 18  Sandstone  24.681088    926.281966      Fault       0.566400
# 19  Sandstone  16.793872           NaN  Anticline       0.368397
# 20  Sandstone  24.165777    930.598738       Dome            NaN
# 21      Shale  12.704460    268.577076  Anticline       0.399866
# 22  Limestone  24.562404           NaN      Fault            NaN
# 23  Limestone  27.455014     85.542568  Anticline       0.042431
# 24      Shale  22.042779    467.344095  Anticline            NaN
# 25      Shale  15.881719    818.058761      Fault       0.401165
# 26  Limestone  19.193256           NaN      Fault            NaN
# 27  Limestone   8.677317           NaN        NaN            NaN
# 28      Shale  23.646028    873.599698  Anticline       0.050556
# 29  Limestone   8.720391    805.206288        NaN            NaN
#
#     Proximity_to_Oil_Field  Estimated_Reservoir_Depth  Oil_Presence
# 0                 2.431355                     2228.0             1
# 1                 2.606158                     1610.0             0
# 2                 1.143136                     2344.0             0
# 3                 2.673532                        NaN             0
# 4                 2.064440                        NaN             0
# 5                 4.927771                     3556.0             1
# 6                 0.439339                        NaN             0
# 7                 4.602919                        NaN             0
# 8                 0.672804                      867.0             0
# 9                 4.097616                        NaN             0
# 10                     NaN                     2909.0             1
# 11                     NaN                      989.0             1
# 12                3.759427                     3371.0             0
# 13                4.130236                     4155.0             1
# 14                     NaN                        NaN             1
# 15                     NaN                        NaN             0
# 16                1.196000                        NaN             0
# 17                0.565441                      916.0             0
# 18                3.502661                        NaN             0
# 19                     NaN                      889.0             0
# 20                4.622036                        NaN             1
# 21                0.939488                      618.0             0
# 22                     NaN                        NaN             1
# 23                4.491105                     1853.0             0
# 24                0.924625                     3171.0             0
# 25                     NaN                        NaN             1
# 26                     NaN                        NaN             1
# 27                4.474662                     3630.0             0
# 28                0.784268                        NaN             1
# 29                1.591426                        NaN             0
